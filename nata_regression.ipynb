# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
complete_houses = pd.read_csv('complete_houses.csv')

# %%
all_columns = ['id','Zip',	'Price',	'Price of square meter',	'Living area',	'Number of rooms',	'Garden surface',	'Terrace surface',	'Open fire',	'Surface of the land',	'Number of facades',	'Swimming pool','Building Cond. values','Kitchen values','Primary energy consumption',	'Energy efficiency']

# %%
no_price_columns = all_columns = ['Zip', 'Living area',	'Number of rooms',	'Garden surface',	'Terrace surface',	'Open fire',	'Surface of the land',	'Number of facades',	'Swimming pool','Building Cond. values','Kitchen values','Primary energy consumption',	'Energy efficiency']

# %%
complete_houses = complete_houses[all_columns]

# %%
#all data we have including our target -'price', not used for training 
complete_houses
# Out:
#        Zip  Living area  Number of rooms  Garden surface  Terrace surface  \
# 0     4000        216.0              5.0          1800.0              0.0
# 1     4400        182.0              3.0          1000.0              0.0
# 2     1420        274.0              3.0          1428.0             62.0
# 3     4020        112.0              3.0            35.0            100.0
# 4     9600        132.0              3.0            80.0             20.0
# ...    ...          ...              ...             ...              ...
# 8783  3540        143.0              3.0             0.0              6.0
# 8784  9240        125.0              2.0             0.0             12.8
# 8785  9300        126.0              3.0             0.0              0.0
# 8786  1500        171.0              5.0             0.0              0.0
# 8787  8500        215.0              4.0            59.2             10.0
#
#       Open fire  Surface of the land  Number of facades  Swimming pool  \
# ...

# %%
# creating independent data that is used for training

houses_without_price = complete_houses[no_price_columns]

# %%
#independent data that is used for training
houses_without_price
# Out:
#        Zip  Living area  Number of rooms  Garden surface  Terrace surface  \
# 0     4000        216.0              5.0          1800.0              0.0
# 1     4400        182.0              3.0          1000.0              0.0
# 2     1420        274.0              3.0          1428.0             62.0
# 3     4020        112.0              3.0            35.0            100.0
# 4     9600        132.0              3.0            80.0             20.0
# ...    ...          ...              ...             ...              ...
# 8783  3540        143.0              3.0             0.0              6.0
# 8784  9240        125.0              2.0             0.0             12.8
# 8785  9300        126.0              3.0             0.0              0.0
# 8786  1500        171.0              5.0             0.0              0.0
# 8787  8500        215.0              4.0            59.2             10.0
#
#       Open fire  Surface of the land  Number of facades  Swimming pool  \
# ...
